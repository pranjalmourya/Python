# %%
x = 5
for i in range(3):
    x = x + i
print(x)
#option A. 8, B.11, C. 10, D. 5
# Out:
# 8

# %%
x = 5
while (n : = x) > 0:
    x -= 2
print(n)  
#option A. 5, B. 1, C. -1, D. Error
# Out:
#   File "/tmp/ipykernel_33/853418851.py", line 2
#     while (n = x) > 0:
#              ^
# SyntaxError: invalid syntax

# %%
def bill(a,b,c=0):
    return a + b+ c
print(bill(100,50))
#option A. 150, B. 100, C. Error, D. 0
# Out:
# 150

# %%
a = [1,2,3,4]
for i in a:
    for j in range(2):
        if i % 2==0:
             a.remove(i)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33/2567505176.py in <module>
#       3     for j in range(2):
#       4         if i % 2==0:
# ----> 5              a.remove(i)
#       6 print(a)
#
# ValueError: list.remove(x): x not in list

# %%
def balance(b):
    if b < 100:
        return "Low"
    return "OK"
print(balance(99))
#option A. Low, B. OK, C. Error, D. None
# Out:
# Low

# %%
x = [1,2,3]
y = x.copy()
y.append(4)
print(x)
#option A. [1,2,3], B. [1,2,3,4], C. Error
# Out:
# [1, 2, 3]

# %%
def fun():
    print("Hi")
for i in range(3):
    fun()
#option A. Hi, B. HiHi, C. HiHiHi,  C. Error
# Out:
# Hi
# Hi
# Hi

# %%
nums = [1,2,3]
print(nums *0)
#option A. [], B. [1,2,3], C. Error
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
d = {}
for i in range(3):
    print(i,'i')
    for j in range(i):
        print(j,'j')
        d[j] = d.get(j,0)+1
        print(d)
# Out:
# 0 i
# 1 i
# 0 j
# {0: 1}
# 2 i
# 0 j
# {0: 2}
# 1 j
# {0: 2, 1: 1}

# %%
b = {}
print(d.get(1,2)+5)
# Out:
# 6

# %%
  for j in range(0):
        print(j)
print(j)
# Out:
# 1
